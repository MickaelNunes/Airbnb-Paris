# %% [markdown]
# # Airbnb listings in Paris 🏡

# %% [markdown]
# ---

# %% [markdown]
# <img src="https://fintech-mag.com/wp-content/uploads/2018/03/paul-dufour-175889-unsplash.jpg" />
#
# Photo by [Paul Dufour](https://unsplash.com/@bill_bokeh)

# %% [markdown]
# Let's go deeper in our understanding of data visualizations and in our skills at manipulating real life data.
#
# In this challenge, we will explore **Airbnb data from Paris listings**. The objective is to answer the following question:
#
# > **How does location impact listing price?**
#
# The data, that you will collect from [InsideAirbnb](http://insideairbnb.com/get-the-data.html) is a very complete dataset of Airbnb listings.
#
# Feel free to play around, and to draw visualizations in order to better understand the data.

# %% [markdown]
# **Q1**. 🇫🇷 Download and load data of **Airbnb Paris listings** from http://insideairbnb.com/.
#
# > 🔦 **Hint**: For extracting a `.gz` file using command line, run:
# > ``` bash
# > gunzip archive.gz
# > ```
#
# - How many lines and columns does it contain?
# - As it contains many columns, some do not appear with `head` method. Print the names of the different columns.

# %%
# TODO - Download and load dataset
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
pd.options.display.max_columns = (96)
df = pd.read_csv('listings.csv')
df
# Out:
# /Users/mickaelnunes/bin/anaconda/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (43,61,62) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#              id                            listing_url       scrape_id  \
# 0          2577      https://www.airbnb.com/rooms/2577  20181207151406
# 1          3109      https://www.airbnb.com/rooms/3109  20181207151406
# 2          5396      https://www.airbnb.com/rooms/5396  20181207151406
# 3          7397      https://www.airbnb.com/rooms/7397  20181207151406
# 4          7964      https://www.airbnb.com/rooms/7964  20181207151406
# 5          8522      https://www.airbnb.com/rooms/8522  20181207151406
# 6          9359      https://www.airbnb.com/rooms/9359  20181207151406
# 7          9952      https://www.airbnb.com/rooms/9952  20181207151406
# 8         10010     https://www.airbnb.com/rooms/10010  20181207151406
# 9         10270     https://www.airbnb.com/rooms/10270  20181207151406
# 10        10586     https://www.airbnb.com/rooms/10586  20181207151406
# 11        10588     https://www.airbnb.com/rooms/10588  20181207151406
# 12        10710     https://www.airbnb.com/rooms/10710  20181207151406
# 13        11170     https://www.airbnb.com/rooms/11170  20181207151406
# 14        11213     https://www.airbnb.com/rooms/11213  20181207151406
# 15        11265     https://www.airbnb.com/rooms/11265  20181207151406
# 16        11487     https://www.airbnb.com/rooms/11487  20181207151406
# 17        11798     https://www.airbnb.com/rooms/11798  20181207151406
# 18        11848     https://www.airbnb.com/rooms/11848  20181207151406
# 19        12268     https://www.airbnb.com/rooms/12268  20181207151406
# 20        12452     https://www.airbnb.com/rooms/12452  20181207151406
# 21        14011     https://www.airbnb.com/rooms/14011  20181207151406
# 22        14264     https://www.airbnb.com/rooms/14264  20181207151406
# 23        14757     https://www.airbnb.com/rooms/14757  20181207151406
# 24        16455     https://www.airbnb.com/rooms/16455  20181207151406
# 25        16457     https://www.airbnb.com/rooms/16457  20181207151406
# 26        16469     https://www.airbnb.com/rooms/16469  20181207151406
# 27        16626     https://www.airbnb.com/rooms/16626  20181207151406
# 28        17283     https://www.airbnb.com/rooms/17283  20181207151406
# 29        17287     https://www.airbnb.com/rooms/17287  20181207151406
# ...         ...                                    ...             ...
# 59851  30588259  https://www.airbnb.com/rooms/30588259  20181207151406
# 59852  30588590  https://www.airbnb.com/rooms/30588590  20181207151406
# 59853  30589090  https://www.airbnb.com/rooms/30589090  20181207151406
# 59854  30589615  https://www.airbnb.com/rooms/30589615  20181207151406
# 59855  30589813  https://www.airbnb.com/rooms/30589813  20181207151406
# 59856  30590162  https://www.airbnb.com/rooms/30590162  20181207151406
# 59857  30590721  https://www.airbnb.com/rooms/30590721  20181207151406
# 59858  30591231  https://www.airbnb.com/rooms/30591231  20181207151406
# 59859  30591953  https://www.airbnb.com/rooms/30591953  20181207151406
# 59860  30594240  https://www.airbnb.com/rooms/30594240  20181207151406
# 59861  30597137  https://www.airbnb.com/rooms/30597137  20181207151406
# 59862  30597336  https://www.airbnb.com/rooms/30597336  20181207151406
# 59863  30597650  https://www.airbnb.com/rooms/30597650  20181207151406
# 59864  30602452  https://www.airbnb.com/rooms/30602452  20181207151406
# 59865  30604188  https://www.airbnb.com/rooms/30604188  20181207151406
# 59866  30605791  https://www.airbnb.com/rooms/30605791  20181207151406
# 59867  30606740  https://www.airbnb.com/rooms/30606740  20181207151406
# 59868  30608375  https://www.airbnb.com/rooms/30608375  20181207151406
# 59869  30609227  https://www.airbnb.com/rooms/30609227  20181207151406
# 59870  30611455  https://www.airbnb.com/rooms/30611455  20181207151406
# 59871  30612200  https://www.airbnb.com/rooms/30612200  20181207151406
# 59872  30615133  https://www.airbnb.com/rooms/30615133  20181207151406
# 59873  30617682  https://www.airbnb.com/rooms/30617682  20181207151406
# 59874  30617963  https://www.airbnb.com/rooms/30617963  20181207151406
# 59875  30621138  https://www.airbnb.com/rooms/30621138  20181207151406
# 59876  30621199  https://www.airbnb.com/rooms/30621199  20181207151406
# 59877  30627500  https://www.airbnb.com/rooms/30627500  20181207151406
# 59878  30630615  https://www.airbnb.com/rooms/30630615  20181207151406
# 59879  30637928  https://www.airbnb.com/rooms/30637928  20181207151406
# 59880  30638025  https://www.airbnb.com/rooms/30638025  20181207151406
#
#       last_scraped                                               name  \
# 0       2018-12-08                   Loft for 4 by Canal Saint Martin
# 1       2018-12-08                                       zen and calm
# 2       2018-12-08                     Explore the heart of old Paris
# 3       2018-12-08                   MARAIS - 2ROOMS APT - 2/4 PEOPLE
# 4       2018-12-08                  Large & sunny flat with balcony !
# 5       2018-12-08                            GREAT FLAT w/ CITY VIEW
# 6       2018-12-08    Cozy, Central Paris: WALK or VELIB EVERYWHERE !
# 7       2018-12-08                          Paris petit coin douillet
# 8       2018-12-08                   Paris view from my balcony - B&B
# 9       2018-12-08                Be charmed by real Paris 11th - B&B
# 10      2018-12-08                                Montmartre Studio 7
# 11      2018-12-08                               Montmartre Studio 10
# 12      2018-12-08                Calm  place in a "bourgeois" area !
# 13      2018-12-08                               QUARTIER LATIN APART
# 14      2018-12-08                                     DOWNTOWN PARIS
# 15      2018-12-08                   Elegant appartment in Montmartre
# 16      2018-12-08                      Old Paris,brand new aparment.
# 17      2018-12-08                        Loft very charming in Paris
# 18      2018-12-08                              Swishy Cosy Paris Pad
# 19      2018-12-08                Faubourg Saint Antoine-chambrecalme
# 20      2018-12-08       De Place Voltaire à Chemin vert. Paris 11ème
# 21      2018-12-08                      Flat-bohemian SoPi Montmartre
# 22      2018-12-08                Charming sunny 2BR in Montmartre !
# 23      2018-12-08                           Lovely Studio Montmartre
# 24      2018-12-08                   Spacious, Light-Filled Apartment
# 25      2018-12-08                            ***ROOFTOP LE MARAIS***
# 26      2018-12-08                       Studio30m2 channel stmartin
# 27      2018-12-08                                Luxury in St Michel
# 28      2018-12-08                 Charming Appartment Goncourt Paris
# 29      2018-12-08                  Your Loft / One of a kind / Paris
# ...            ...                                                ...
# 59851   2018-12-08                                Paris à la campagne
# 59852   2018-12-08  LUMINOUS APARTMENT IN THE NECKER DISTRICT IN P...
# 59853   2018-12-08                      Appartement lumineux et calme
# 59854   2018-12-08                           paris la place de clichy
# 59855   2018-12-08                 Elegant room in the heart of Paris
# 59856   2018-12-08       Charmant appartement T2 35m2 très bien situé
# 59857   2018-12-08    Grand appartement 1 chambre proche Montparnasse
# 59858   2018-12-08                    Paris Près de Bastille DELAGARE
# 59859   2018-12-08    Beau Pied-à-terre au centre de Paris - 2 Pièces
# 59860   2018-12-08        Basic studio apartment in student residence
# 59861   2018-12-08   Dream loft with private patio near Nation for 6p
# 59862   2018-12-08              Studio in paris Eiffel Tower district
# 59863   2018-12-08                  Charming cozy studio near Pigalle
# 59864   2018-12-08      proche du métro bus idéale pour visiter Paris
# 59865   2018-12-08        Cosy Apartment with Backyard - Montparnasse
# 59866   2018-12-08                             studio aux batignolles
# 59867   2018-12-08                 Classic Les Halles Studio longterm
# 59868   2018-12-08                            Agréable séjour à Paris
# 59869   2018-12-08      Coin de paradis avec vue imprenable sur Paris
# 59870   2018-12-08       Bel appartement à Paris, quartier République
# 59871   2018-12-08  Exquisite Flat In Posh District Near Eiffel To...
# 59872   2018-12-08                              Standing Calm Central
# 59873   2018-12-08          Appartement cosy pour les fêtes de Noel !
# 59874   2018-12-08    Functionnal & Cosy Flat In Northern Paris For 4
# 59875   2018-12-08        Beautiful Top floor studio/Sacre Coeur view
# 59876   2018-12-08          Charming and Calme Studio for two Persons
# 59877   2018-12-08                Studio récent 28m2 au bord de Paris
# 59878   2018-12-08                     Studio charme, Canal St Martin
# 59879   2018-12-08        LUXURY APARTMENT - Etoile / Arc de Triomphe
# 59880   2018-12-08                                 Au coeur du 11ème.
#
#                                                  summary  \
# 0      100 m2 loft (1100 sq feet) with high ceiling, ...
# 1      Appartement très calme de 50M2 Belle lumière D...
# 2      Cozy, well-appointed and graciously designed s...
# 3              VERY CONVENIENT, WITH THE BEST LOCATION !
# 4      Very large & nice apartment all for you!  - Su...
# 5                                                    NaN
# 6      Location! Location! Location! Just bring your ...
# 7                                                    NaN
# 8      A real "home from home" in the heart of Paris ...
# 9      Here you will find a true home from home in Pa...
# 10     LONG TERM RENTAL Available  The studio is situ...
# 11     LONG TERM RENTAL 12 MONTHS  - 9 MONTHS for STU...
# 12                                                   NaN
# 13                                                   NaN
# 14     Numéro d'enregistrement Ville de Paris (Phone ...
# 15     Located in lively and charming Montmartre, in ...
# 16                                                   NaN
# 17     Mon appartement est situé dans une très jolie ...
# 18     ***SWISHY COSY PAD*** The apartment is on the ...
# 19                                                   NaN
# 20     Appartement lumineux au 4ème étage d'un immeub...
# 21     Cosy 3-room apartment fully furnished in Paris...
# 22     Charming and typical apartment in the heart of...
# 23     Our studio is located in the very heart of Mon...
# 24     Our apartment is spacious, bright, centrally-l...
# 25     STUDIO @ Le Marais Central location, 100m from...
# 26                                                   NaN
# 27     Beautiful XV century "hotel particulier". This...
# 28                                                   NaN
# 29     Loft across from the Parc de la vilette 3 leve...
# ...                                                  ...
# 59851  A 5 minutes des quartiers pittoresques de Mouf...
# 59852  Charming apartment in the 15th arrondissement,...
# 59853  Appartement lumineux au 13ème étage d'un quart...
# 59854  studio au 6 eme étage sans ascenseur . a place...
# 59855  Want to enjoy a stay in Paris under the French...
# 59856  Charmant appartement type T2 de 35m2 avec le c...
# 59857    Ambiance calme proche de l'agitation de la gare
# 59858                                                NaN
# 59859  Joli pied-à-terre parisien avec poutres ancien...
# 59860  Basic studio apartment in a student residence ...
# 59861  Welcome to my dream flat! Be amazed by this st...
# 59862                                                NaN
# 59863  Beautiful studio, both comfortable, warm and s...
# 59864  Cosy idéale pour Visiter Paris, bus juste à 1 ...
# 59865  Very Cosy apartment located in the heart of pa...
# 59866  studio de 20m2 lumineux, fonctionnel et propre...
# 59867  Härlig och mysig studio i hjärtat av Paris, va...
# 59868  Bel appartement de deux chambres, lumineux et ...
# 59869  Notre appartement est situé au plus haut de Mo...
# 59870  Appartement typiquement Parisien, très lumineu...
# 59871  Beautiful spacious flat in the poshest and mos...
# 59872  This apartment for 4 people is perfectly locat...
# 59873  Nous mettons à disposition notre appartement d...
# 59874  Honest, and very functional apartment ready fo...
# 59875  Beautiful top floor apartment in the middle of...
# 59876  20m2 studio near avenue Foch in a very quiet s...
# 59877  Charmant studio de 28m2 dans un quartier neuf ...
# 59878  Studio chaleureux situé sur le canal St Martin...
# 59879  Luxury fully-renovated Apartment,  in a beauti...
# 59880                                   Studio au calme.
#
#                                                    space  \
# 0      The district has any service or shop you may d...
# 1                       I bedroom appartment in Paris 14
# 2      Small, well appointed studio apartment at the ...
# 3      PLEASE ASK ME BEFORE TO MAKE A REQUEST !!! No ...
# 4      hello ! We have a great 75 square meter apartm...
# 5      Really nice flat located in the 20th district ...
# 6      Since I live in the USA, it is difficult to ma...
# 7      Make your stay in Paris a perfect experience. ...
# 8      Enjoy a slice of Parisian history and stay in ...
# 9      Here you will find a true home from home so th...
# 10     The studio is an open living space measuring 2...
# 11     The studio has lots of natural light and has b...
# 12     Very close to Place de la Concorde and Madelei...
# 13     Description The apartment is located in the we...
# 14     (Description first in English then in French) ...
# 15     The appartment is 60 m2 large. 4th floor with ...
# 16     Brand new renovated studio with living room, b...
# 17     46 square meters It's a loft with only one roo...
# 18     FULLY RENOVATED THREE YEARS AGO - NON SMOKING ...
# 19     Chambre très claire, calme, sur le jardin dans...
# 20     Old french style apartment (57m2) in the heart...
# 21     ALWAYS MESSAGE ME BEFORE BOOKING IN ORDER TO G...
# 22     Beautifully furnished 1-2 bedrooms spacious ap...
# 23     Modern and charming studio in the butte Montma...
# 24     Our apartment is spacious, bright, centrally-l...
# 25     Very charming for 1 or 2 person (couples only,...
# 26     Studio30m2 channel stmartin  My studio is loca...
# 27     In the very heart of Paris also known as "Quar...
# 28     A very quiet place, rue du Faubourg du Temple,...
# 29     Metro: line 7 (Porte de la vilette)is less tha...
# ...                                                  ...
# 59851  Sur fond de murs en pierres apparentes, un mob...
# 59852  Charming apartment in the 15th arrondissement,...
# 59853  Paris 14th district, 2 bedroom flat suitable f...
# 59854                                                NaN
# 59855  A spacious room of12 to 14sqm will host you fo...
# 59856  Appartement type T2 avec tout le charme de l'a...
# 59857      Appartement 36 m2, 1 chambre, 1 salle de bain
# 59858                                                NaN
# 59859  Le charme de l'appartement réside dans ses pou...
# 59860                                                NaN
# 59861  It is located on the ground floor and has a mo...
# 59862                                                NaN
# 59863  Superb cozy and bright studio of 26m2 on the g...
# 59864                           La cuisine salle de bain
# 59865                                                NaN
# 59866                                                NaN
# 59867                                                NaN
# 59868                                                NaN
# 59869  Situé à deux pas de la basilique du Sacré Cœur...
# 59870  Appartement de 2 chambres situé au centre de P...
# 59871  CAREFUL : SPOILER ALERT !!  1) What is so cool...
# 59872                                                NaN
# 59873                                                NaN
# 59874  1) What is so cool about the flat:  - very wel...
# 59875  Welcome to my flat in the eart of Montmartre, ...
# 59876  Studio de 20m2 à proximité de l'avenue Foch da...
# 59877                                                NaN
# 59878                                                NaN
# 59879  At home in Paris... An incredible hideaway if ...
# 59880                                                NaN
#
#                                              description experiences_offered  \
# 0      100 m2 loft (1100 sq feet) with high ceiling, ...                none
# 1                       I bedroom appartment in Paris 14                none
# 2      Cozy, well-appointed and graciously designed s...                none
# 3      VERY CONVENIENT, WITH THE BEST LOCATION ! PLEA...                none
# 4      Very large & nice apartment all for you!  - Su...                none
# 5      Really nice flat located in the 20th district ...                none
# 6      Location! Location! Location! Just bring your ...                none
# 7      Make your stay in Paris a perfect experience. ...                none
# 8      A real "home from home" in the heart of Paris ...                none
# 9      Here you will find a true home from home in Pa...                none
# 10     LONG TERM RENTAL Available  The studio is situ...                none
# 11     LONG TERM RENTAL 12 MONTHS  - 9 MONTHS for STU...                none
# 12     Very close to Place de la Concorde and Madelei...                none
# 13     Description The apartment is located in the we...                none
# 14     Numéro d'enregistrement Ville de Paris (Phone ...                none
# 15     Located in lively and charming Montmartre, in ...                none
# 16     Brand new renovated studio with living room, b...                none
# 17     Mon appartement est situé dans une très jolie ...                none
# 18     FULLY RENOVATED THREE YEARS AGO - NON SMOKING ...                none
# 19     Chambre très claire, calme, sur le jardin dans...                none
# 20     Appartement lumineux au 4ème étage d'un immeub...                none
# 21     Cosy 3-room apartment fully furnished in Paris...                none
# 22     Beautifully furnished 1-2 bedrooms spacious ap...                none
# 23     Our studio is located in the very heart of Mon...                none
# 24     Our apartment is spacious, bright, centrally-l...                none
# 25     STUDIO @ Le Marais Central location, 100m from...                none
# 26     Studio30m2 channel stmartin  My studio is loca...                none
# 27     Beautiful XV century "hotel particulier". This...                none
# 28     A very quiet place, rue du Faubourg du Temple,...                none
# 29     Loft across from the Parc de la vilette 3 leve...                none
# ...                                                  ...                 ...
# 59851  A 5 minutes des quartiers pittoresques de Mouf...                none
# 59852  Charming apartment in the 15th arrondissement,...                none
# 59853  Paris 14th district, 2 bedroom flat suitable f...                none
# 59854  studio au 6 eme étage sans ascenseur . a place...                none
# 59855  Want to enjoy a stay in Paris under the French...                none
# 59856  Charmant appartement type T2 de 35m2 avec le c...                none
# 59857  Ambiance calme proche de l'agitation de la gar...                none
# 59858                                                NaN                none
# 59859  Joli pied-à-terre parisien avec poutres ancien...                none
# 59860  Basic studio apartment in a student residence ...                none
# 59861  Welcome to my dream flat! Be amazed by this st...                none
# 59862                                                NaN                none
# 59863  Beautiful studio, both comfortable, warm and s...                none
# 59864  Cosy idéale pour Visiter Paris, bus juste à 1 ...                none
# 59865  Very Cosy apartment located in the heart of pa...                none
# 59866  studio de 20m2 lumineux, fonctionnel et propre...                none
# 59867  Härlig och mysig studio i hjärtat av Paris, va...                none
# 59868  Bel appartement de deux chambres, lumineux et ...                none
# 59869  Notre appartement est situé au plus haut de Mo...                none
# 59870  Appartement typiquement Parisien, très lumineu...                none
# 59871  Beautiful spacious flat in the poshest and mos...                none
# 59872  This apartment for 4 people is perfectly locat...                none
# 59873  Nous mettons à disposition notre appartement d...                none
# 59874  Honest, and very functional apartment ready fo...                none
# 59875  Beautiful top floor apartment in the middle of...                none
# 59876  20m2 studio near avenue Foch in a very quiet s...                none
# 59877  Charmant studio de 28m2 dans un quartier neuf ...                none
# 59878  Studio chaleureux situé sur le canal St Martin...                none
# 59879  Luxury fully-renovated Apartment,  in a beauti...                none
# 59880                                   Studio au calme.                none
#
#                                    neighborhood_overview  \
# 0                                                    NaN
# 1                                                    NaN
# 2      You are within walking distance to the Louvre,...
# 3                                                    NaN
# 4                                                    NaN
# 5                                                    NaN
# 6                                                    NaN
# 7                                                    NaN
# 8      This area typically Parisian, is nice, trendy ...
# 9      This area typically Parisian, is nice, trendy ...
# 10     Montmartre, the neighborhood surrounding the s...
# 11     Montmartre, the neighborhood surrounding the s...
# 12                                                   NaN
# 13                                                   NaN
# 14     Nous sommes dans le quartier de Belleville, en...
# 15     The apartment is located at the foot of charmi...
# 16                                                   NaN
# 17     Near china town and very convenient to be quic...
# 18                                                   NaN
# 19                                                   NaN
# 20     Le 11e est un ancien quartier d'artisans, avec...
# 21     I will send you via email all the required det...
# 22                                                   NaN
# 23     The studio is without any doubt located in one...
# 24     A huge park, some smaller ones (and a little g...
# 25     Very lively area, plenty of bars, restaurants ...
# 26                                                   NaN
# 27     Great situation next to Odeon, Saint Germain d...
# 28                                                   NaN
# 29                                                   NaN
# ...                                                  ...
# 59851  Amoureux de l'histoire du vieux Paris et de so...
# 59852                                                NaN
# 59853                                                NaN
# 59854                                                NaN
# 59855  Se situant auprès du quartier Saint-Germain-De...
# 59856  Quartier proche de tout mais éloigné du tumult...
# 59857                                                NaN
# 59858                                                NaN
# 59859  Quartier Bonne Nouvelle, dynamique mais l'appa...
# 59860                                                NaN
# 59861  You will find a true Parisian experience in th...
# 59862                                                NaN
# 59863  The 9th arrondissement of Paris is a rather pl...
# 59864                                                NaN
# 59865  Located in a very popular street with every ki...
# 59866  Nous sommes juste à côté du sacré-coeur de Mon...
# 59867                                                NaN
# 59868                                                NaN
# 59869  Marchez sur les pas d'Amélie Poulain ! Profite...
# 59870  Il est situé dans un environnement de commerce...
# 59871  The 16th arrondissement of Paris (XVIe arrondi...
# 59872  All types of restaurants around the neighborho...
# 59873                                                NaN
# 59874  The 18th arrondissement of Paris (XVIIIe arron...
# 59875  Montmartre otherwise known as The Mountain Of ...
# 59876                           Very chic and calm area.
# 59877                                                NaN
# 59878                                                NaN
# 59879                                                NaN
# 59880                                                NaN
#
#                                                    notes  \
# 0                                                    NaN
# 1                                                    NaN
# 2      The staircase leading up to the apartment is n...
# 3      Important: Be conscious that an apartment in a...
# 4                                                    NaN
# 5                                                    NaN
# 6                                 Velib station outside.
# 7                                                    NaN
# 8      We participated in the very beginning of the A...
# 9      We participated in the very beginning of the A...
# 10                                                   NaN
# 11                                                   NaN
# 12                                                   NaN
# 13                                                   NaN
# 14     Important remarks / Remarques importantes    W...
# 15                           Folding baby bed available.
# 16                                                   NaN
# 17                                                   NaN
# 18                                                   NaN
# 19                                                   NaN
# 20     L'appartement est prévu pour 4 personnes maxim...
# 21                                                   NaN
# 22                                                   NaN
# 23     Don't hesitate to ask us for our favorite and ...
# 24     Please don't make a reservation request withou...
# 25     Please read carefully the ad, all details are ...
# 26                                                   NaN
# 27                                                   NaN
# 28                                                   NaN
# 29                                                   NaN
# ...                                                  ...
# 59851                                                NaN
# 59852                                                NaN
# 59853                                                NaN
# 59854                                                NaN
# 59855  Making travelers' well being one of our main v...
# 59856                                                NaN
# 59857                                                NaN
# 59858                                                NaN
# 59859                                                NaN
# 59860                                                NaN
# 59861  An extra fee of 20€ will be charged for check-...
# 59862                                                NaN
# 59863                                                NaN
# 59864                                                NaN
# 59865                                                NaN
# 59866                                                NaN
# 59867                                                NaN
# 59868                                                NaN
# 59869                                                NaN
# 59870                                                NaN
# 59871  1) Before your arrival, we will, of course, ag...
# 59872                                                NaN
# 59873                                                NaN
# 59874  1) Before your arrival, we will, of course, ag...
# 59875                                                NaN
# 59876                                                NaN
# 59877                                                NaN
# 59878                                                NaN
# 59879  If you want a cot, a baby high chair at your d...
# 59880                                                NaN
#
#                                                  transit  \
# 0                          Metro lines : 4, 8, 3, 11, 9.
# 1                            ligne 13 and RER B, Ligne 4
# 2      The flat is close to two or three major metro ...
# 3      Metro station HÖTEL-DE-VILLE is 100 meters close.
# 4                                                    NaN
# 5                                                    NaN
# 6      All the major metros and RERs are at Les Halle...
# 7                                                    NaN
# 8      I can also organize transport service.Easy acc...
# 9      Easy access from the train stations and airpor...
# 10     The studio can be easily accessed by the RER, ...
# 11       The studio can be easily accessed by the RER...
# 12                                                   NaN
# 13                                                   NaN
# 14     Closest Métro stations : Belleville (Lines 2 a...
# 15     Métro Abbesses at 50 mètres, ligne 12,  crossi...
# 16                                                   NaN
# 17                     Line 14 Tramway N°2 Subway line 7
# 18                                                   NaN
# 19                                                   NaN
# 20     Transports publics faciles et variés : autobus...
# 21     You can easily take the metro or the bus If yo...
# 22                                                   NaN
# 23     The flat is nearby the following stations :  -...
# 24     Super convenient public transportation.  Two m...
# 25     Very central, metro station nearby. Line 1, "S...
# 26                                                   NaN
# 27     Two near by metros line 10 and 4 and direct fr...
# 28                                                   NaN
# 29                                                   NaN
# ...                                                  ...
# 59851  Je ne manquerai pas de renseigner mes hôtes su...
# 59852                                                NaN
# 59853                                                NaN
# 59854                                                NaN
# 59855  Located in the heart of the Saint-Germain dist...
# 59856    Ligne 6 Glaciere Bus 21 RER B Denfert Rochereau
# 59857                                                NaN
# 59858                                                NaN
# 59859  4 lignes de métro à 2 minutes A 10 minutes de ...
# 59860                                                NaN
# 59861  The district couldn't be better served! Métro ...
# 59862                                                NaN
# 59863                       Metro line 2 Anvers at 4 min
# 59864                                                NaN
# 59865                                                NaN
# 59866  Le quartier est pratique en transport pour se ...
# 59867                                                NaN
# 59868                                                NaN
# 59869  Vous pouvez vous balader dans les rues commerç...
# 59870  L'appartement est proche des métros Oberkampf ...
# 59871  By metro: - stop "Exelmans" - stop "Chardon La...
# 59872  The apartment is three subway stops from Gare ...
# 59873                                                NaN
# 59874  By metro: - stop "Max Dormoy" By bus: - countl...
# 59875  Anvers Metrostation, and Barbès – Rochechouart...
# 59876  Close to two main metro line 2 and 1 Argentine...
# 59877                                                NaN
# 59878                                                NaN
# 59879                                                NaN
# 59880                                                NaN
#
#                                                   access  \
# 0                                                    NaN
# 1                                                    NaN
# 2      The flat includes its own modern bathroom, a w...
# 3                                                    NaN
# 4                  You have access to all the apartment.
# 5                                                    NaN
# 6      You are alone in the flat, the entire city is ...
# 7      Cet appartement n est pas accessible aux Handi...
# 8      Services and equipment :  free wireless intern...
# 9      The price includes : Breakfast provided to pre...
# 10     There is a phone with free calls in France and...
# 11      There is a telephone with free calls in Franc...
# 12                                                   NaN
# 13                                                   NaN
# 14     Renters have access to the full flat /Les voya...
# 15                                                   NaN
# 16                                                   NaN
# 17                                       TV Wifi Fridge
# 18                                                   NaN
# 19                                                   NaN
# 20                                       Logement entier
# 21                                                   NaN
# 22                                                   NaN
# 23     The dwelling is entirely at the disposal of th...
# 24     Guests can use the piano, but pianists who mak...
# 25                                    All the apartment.
# 26                                                   NaN
# 27     The private bedroom has it's own private bathr...
# 28                                                   NaN
# 29                                                   NaN
# ...                                                  ...
# 59851                                                NaN
# 59852                                                NaN
# 59853                                                NaN
# 59854                                                NaN
# 59855  Offering you common areas that will remain the...
# 59856                                                NaN
# 59857                                                NaN
# 59858                                                NaN
# 59859      Tout le logement est accessible aux voyageurs
# 59860                                                NaN
# 59861  While I am away you will have the entire flat ...
# 59862                                                NaN
# 59863  Only guests will have access to the apartment ...
# 59864                                                NaN
# 59865                                                NaN
# 59866                                                NaN
# 59867                                                NaN
# 59868                                                NaN
# 59869                                                NaN
# 59870                                                NaN
# 59871  - all bedroom basics : bed linens, pillows, du...
# 59872                                                NaN
# 59873                                                NaN
# 59874  - Wifi & TV access  - all bedroom basics : bed...
# 59875  The entire place is yours when living here. It...
# 59876            You have access to the entire apartment
# 59877                                                NaN
# 59878                                                NaN
# 59879  You will find a 55-inch television with access...
# 59880                                                NaN
#
#                                              interaction  \
# 0                                                    NaN
# 1                                 yes I can help you out
# 2      We expect guests to operate rather independent...
# 3                                                    NaN
# 4      We are there to welcome you, give you keys and...
# 5                                                    NaN
# 6      I am available 18 hours a day by text, have lo...
# 7                                                    NaN
# 8      I welcome you personally on your arrival, I gi...
# 9      I welcome you personally upon arrival, I give ...
# 10                                                   NaN
# 11                                                   NaN
# 12                                                   NaN
# 13                                                   NaN
# 14     I am always happy to help with advice and sugg...
# 15     As soon as reservation firm, I will give all t...
# 16                                                   NaN
# 17                At the begining to explain everything!
# 18                                                   NaN
# 19                                                   NaN
# 20                                                   NaN
# 21     I do my best to answer to all the questions of...
# 22                                                   NaN
# 23     Our guests can phone us at anytime, whether it...
# 24     Of course guests can contact me if they have q...
# 25     Keys provided for your arrival. Deposit is man...
# 26                                                   NaN
# 27     I would be glad to give you tips and advice on...
# 28                                                   NaN
# 29                                                   NaN
# ...                                                  ...
# 59851  Je serais à la disposition de mes hôtes pour l...
# 59852                                                NaN
# 59853  Vous aurez la documentation utile pour les tra...
# 59854                                                NaN
# 59855  Concerned about the smallest detail to make yo...
# 59856                                                NaN
# 59857                                                NaN
# 59858                                                NaN
# 59859                                                NaN
# 59860                                                NaN
# 59861  My friends at Hostmaker are looking after my h...
# 59862                                                NaN
# 59863  To make your stay even better during my absenc...
# 59864                                                NaN
# 59865                                                NaN
# 59866                                                NaN
# 59867                                                NaN
# 59868                                                NaN
# 59869  Nous sommes disponibles via (Hidden by Airbnb)...
# 59870  Les voyageurs peuvent échanger avec nous via e...
# 59871  More than happy to show you around, recommend ...
# 59872  I answer by SMS to all questions during your s...
# 59873                                                NaN
# 59874  More than happy to show you around, recommend ...
# 59875  I will not stay I the apartment, but I will be...
# 59876  I will be here to welcome you. During your sta...
# 59877                                                NaN
# 59878                                                NaN
# 59879  Sheets and towels are provided. Cleaning is do...
# 59880                                                NaN
#
#                                              house_rules  thumbnail_url  \
# 0                                                    NaN            NaN
# 1                                                    NaN            NaN
# 2      This is a small flat in a very old building th...            NaN
# 3      ELECTRICITY INCLUDED FOR NORMAL USING. PLEASE ...            NaN
# 4                                               Respect.            NaN
# 5                                                    NaN            NaN
# 6      This residence is limited to TWO people and is...            NaN
# 7                                   DO NOT USE FIREPLACE            NaN
# 8      You are feeling free in your home away from ho...            NaN
# 9      When you are in this apartment and you are hom...            NaN
# 10                                                   NaN            NaN
# 11                                                   NaN            NaN
# 12     Sanibroyeur neuf dans la salle d'eau : ne rien...            NaN
# 13     For the week-ends the check-in has to be after...            NaN
# 14     out of respect for the next renters and the ow...            NaN
# 15     This appartment is MY appartment 8 months per ...            NaN
# 16                                                   NaN            NaN
# 17     It's my own flat so I wish you to be respectfu...            NaN
# 18     Absolutely non-smoking. 1. Number of Persons/R...            NaN
# 19                                                   NaN            NaN
# 20     Merci d'être discret dans les parties communes...            NaN
# 21     If I were you, I would have a look at the revi...            NaN
# 22                                                   NaN            NaN
# 23                     Smoking and pets are not allowed.            NaN
# 24                              No smoking, and no pets.            NaN
# 25     Non smoking Verified profile required Arrival ...            NaN
# 26     Please, leave the appartment as clean as it wa...            NaN
# 27                                                   NaN            NaN
# 28     Nous demandons une caution de 300€ en espèce à...            NaN
# 29     me casa su casa, as long as you don't leave a ...            NaN
# ...                                                  ...            ...
# 59851                        - pas de bruit aprés minuit            NaN
# 59852  IMPORTANT : check in is between 3pm and 9pm, c...            NaN
# 59853                                                NaN            NaN
# 59854  - pas de bruit pas du événement ou des fête (W...            NaN
# 59855                                                NaN            NaN
# 59856  - Pas de bruit après 22H - Enlever les chaussu...            NaN
# 59857                                                NaN            NaN
# 59858                                                NaN            NaN
# 59859                                                NaN            NaN
# 59860                                                NaN            NaN
# 59861                                                NaN            NaN
# 59862                                                NaN            NaN
# 59863  If not already done, I will ask you to verify ...            NaN
# 59864  Faire ça vaisselle sortir les poubelles et ret...            NaN
# 59865                                                NaN            NaN
# 59866                                                NaN            NaN
# 59867                                - Quite after 21.00            NaN
# 59868                                                NaN            NaN
# 59869  - En semaine, il est préférable d'être discret...            NaN
# 59870                                                NaN            NaN
# 59871                                                NaN            NaN
# 59872                             - No noise after 10 pm            NaN
# 59873               - Appartement dans copropriété calme            NaN
# 59874                                                NaN            NaN
# 59875  - Important: Dont throw anything in the toilet...            NaN
# 59876                                                NaN            NaN
# 59877                                                NaN            NaN
# 59878                                                NaN            NaN
# 59879                                                NaN            NaN
# 59880                                                NaN            NaN
#
#        medium_url                                        picture_url  \
# 0             NaN  https://a0.muscache.com/im/pictures/09da057c-0...
# 1             NaN  https://a0.muscache.com/im/pictures/baeae9e2-c...
# 2             NaN  https://a0.muscache.com/im/pictures/52413/f9bf...
# 3             NaN  https://a0.muscache.com/im/pictures/67928287/3...
# 4             NaN  https://a0.muscache.com/im/pictures/4471349/6f...
# 5             NaN  https://a0.muscache.com/im/pictures/30560/0876...
# 6             NaN  https://a0.muscache.com/im/pictures/c2965945-0...
# 7             NaN  https://a0.muscache.com/im/pictures/52474/aeb7...
# 8             NaN  https://a0.muscache.com/im/pictures/1d8c4fb5-a...
# 9             NaN  https://a0.muscache.com/im/pictures/86310660/d...
# 10            NaN  https://a0.muscache.com/im/pictures/445716/581...
# 11            NaN  https://a0.muscache.com/im/pictures/445734/5d7...
# 12            NaN  https://a0.muscache.com/im/pictures/3387746/9c...
# 13            NaN  https://a0.muscache.com/im/pictures/52563/91b4...
# 14            NaN  https://a0.muscache.com/im/pictures/48419/e691...
# 15            NaN  https://a0.muscache.com/im/pictures/fffd49c6-c...
# 16            NaN  https://a0.muscache.com/im/pictures/50213/7fab...
# 17            NaN  https://a0.muscache.com/im/pictures/22458692/0...
# 18            NaN  https://a0.muscache.com/im/pictures/275149/be0...
# 19            NaN  https://a0.muscache.com/im/pictures/4142889/d4...
# 20            NaN  https://a0.muscache.com/im/pictures/0ad4b5fc-f...
# 21            NaN  https://a0.muscache.com/im/pictures/66072/4f8a...
# 22            NaN  https://a0.muscache.com/im/pictures/11156748/8...
# 23            NaN  https://a0.muscache.com/im/pictures/291a9464-7...
# 24            NaN  https://a0.muscache.com/im/pictures/39476541/f...
# 25            NaN  https://a0.muscache.com/im/pictures/2eda53a0-1...
# 26            NaN  https://a0.muscache.com/im/pictures/56900681/3...
# 27            NaN  https://a0.muscache.com/im/pictures/8bc590bd-5...
# 28            NaN  https://a0.muscache.com/im/pictures/10772267/b...
# 29            NaN  https://a0.muscache.com/im/pictures/48756370/c...
# ...           ...                                                ...
# 59851         NaN  https://a0.muscache.com/im/pictures/5e907199-a...
# 59852         NaN  https://a0.muscache.com/im/pictures/5de71c0b-0...
# 59853         NaN  https://a0.muscache.com/im/pictures/16454860/d...
# 59854         NaN  https://a0.muscache.com/im/pictures/9f81fc11-b...
# 59855         NaN  https://a0.muscache.com/im/pictures/8fc5e000-f...
# 59856         NaN  https://a0.muscache.com/im/pictures/9054e411-5...
# 59857         NaN  https://a0.muscache.com/im/pictures/e6f0800b-5...
# 59858         NaN  https://a0.muscache.com/im/pictures/41971541-e...
# 59859         NaN  https://a0.muscache.com/im/pictures/2afbbfa8-2...
# ...
# 59864                  NaN                t               NaN
# 59865                  NaN                t               NaN
# 59866                  NaN                t               NaN
# 59867                  NaN                t               NaN
# 59868                  NaN                t               NaN
# 59869                  NaN                t               NaN
# 59870                  NaN                t               NaN
# 59871                  NaN                t               NaN
# 59872                  NaN                t               NaN
# 59873                  NaN                t     7511902692006
# 59874                  NaN                t               NaN
# 59875                  NaN                t               NaN
# 59876                  NaN                t               NaN
# 59877                  NaN                t               NaN
# 59878                  NaN                t               NaN
# 59879                  NaN                t               NaN
# 59880                  NaN                t               NaN
#
#       jurisdiction_names instant_bookable is_business_travel_ready  \
# 0                {PARIS}                t                        f
# 1                {PARIS}                f                        f
# 2                {PARIS}                t                        f
# 3                {PARIS}                f                        f
# 4                {PARIS}                f                        f
# 5                {PARIS}                f                        f
# 6                {PARIS}                f                        f
# 7                {PARIS}                f                        f
# 8                {PARIS}                f                        f
# 9                {PARIS}                f                        f
# 10               {PARIS}                f                        f
# 11               {PARIS}                f                        f
# 12               {PARIS}                f                        f
# 13               {PARIS}                f                        f
# 14               {PARIS}                f                        f
# 15               {PARIS}                f                        f
# 16               {PARIS}                f                        f
# 17               {PARIS}                f                        f
# 18               {PARIS}                t                        f
# 19               {PARIS}                f                        f
# 20               {PARIS}                f                        f
# 21               {PARIS}                f                        f
# 22               {PARIS}                t                        f
# 23               {PARIS}                t                        f
# 24               {PARIS}                f                        f
# 25               {PARIS}                f                        f
# 26               {PARIS}                f                        f
# 27               {PARIS}                t                        f
# 28               {PARIS}                t                        f
# 29               {PARIS}                t                        f
# ...                  ...              ...                      ...
# 59851            {PARIS}                t                        f
# 59852            {PARIS}                t                        f
# 59853            {PARIS}                f                        f
# 59854            {PARIS}                t                        f
# 59855            {PARIS}                t                        f
# 59856            {PARIS}                t                        f
# 59857            {PARIS}                f                        f
# 59858            {PARIS}                f                        f
# 59859            {PARIS}                t                        f
# 59860            {PARIS}                f                        f
# 59861            {PARIS}                t                        f
# 59862            {PARIS}                t                        f
# 59863            {PARIS}                t                        f
# 59864            {PARIS}                t                        f
# 59865            {PARIS}                t                        f
# 59866            {PARIS}                f                        f
# 59867            {PARIS}                f                        f
# 59868            {PARIS}                t                        f
# 59869            {PARIS}                t                        f
# 59870            {PARIS}                t                        f
# 59871            {PARIS}                t                        f
# 59872            {PARIS}                t                        f
# 59873            {PARIS}                f                        f
# 59874            {PARIS}                t                        f
# 59875            {PARIS}                f                        f
# 59876            {PARIS}                f                        f
# 59877         {GENTILLY}                t                        f
# 59878            {PARIS}                f                        f
# 59879            {PARIS}                t                        f
# 59880            {PARIS}                t                        f
#
#                cancellation_policy require_guest_profile_picture  \
# 0      strict_14_with_grace_period                             f
# 1                         flexible                             f
# 2      strict_14_with_grace_period                             f
# 3                         moderate                             f
# 4      strict_14_with_grace_period                             f
# 5                         moderate                             f
# 6      strict_14_with_grace_period                             t
# 7      strict_14_with_grace_period                             f
# 8      strict_14_with_grace_period                             f
# 9      strict_14_with_grace_period                             f
# 10     strict_14_with_grace_period                             t
# 11     strict_14_with_grace_period                             t
# 12                        moderate                             f
# 13                        moderate                             f
# 14                        flexible                             f
# 15     strict_14_with_grace_period                             f
# 16     strict_14_with_grace_period                             f
# 17                        moderate                             f
# 18     strict_14_with_grace_period                             f
# 19                        moderate                             f
# 20                        flexible                             f
# 21     strict_14_with_grace_period                             t
# 22     strict_14_with_grace_period                             f
# 23                        flexible                             f
# 24     strict_14_with_grace_period                             f
# 25                        moderate                             t
# 26                        moderate                             f
# 27     strict_14_with_grace_period                             f
# 28     strict_14_with_grace_period                             f
# 29                        moderate                             f
# ...                            ...                           ...
# 59851                     flexible                             f
# 59852                     moderate                             f
# 59853                     flexible                             f
# 59854  strict_14_with_grace_period                             f
# 59855                     flexible                             f
# 59856                     flexible                             f
# 59857                     flexible                             f
# 59858  strict_14_with_grace_period                             f
# 59859  strict_14_with_grace_period                             f
# 59860  strict_14_with_grace_period                             f
# 59861                     moderate                             f
# 59862                     flexible                             f
# 59863  strict_14_with_grace_period                             f
# 59864                     flexible                             f
# 59865                     flexible                             f
# 59866                     flexible                             f
# 59867  strict_14_with_grace_period                             f
# 59868                     flexible                             f
# 59869                     flexible                             f
# 59870  strict_14_with_grace_period                             f
# 59871                     flexible                             f
# 59872  strict_14_with_grace_period                             f
# 59873                     flexible                             f
# 59874                     flexible                             f
# 59875                     flexible                             f
# 59876  strict_14_with_grace_period                             f
# 59877                     flexible                             f
# 59878                     flexible                             f
# 59879  strict_14_with_grace_period                             f
# 59880                     flexible                             f
#
#       require_guest_phone_verification  calculated_host_listings_count  \
# 0                                    f                               1
# 1                                    f                               1
# 2                                    f                               1
# 3                                    f                               1
# 4                                    f                               1
# 5                                    f                               1
# 6                                    t                               1
# 7                                    f                               1
# 8                                    f                               6
# 9                                    f                               6
# 10                                   t                               3
# 11                                   t                               3
# 12                                   f                               1
# 13                                   t                               1
# 14                                   f                               2
# 15                                   f                               1
# 16                                   f                               1
# 17                                   f                               1
# 18                                   f                               1
# 19                                   f                               2
# 20                                   f                               1
# 21                                   t                               1
# 22                                   f                               1
# 23                                   f                               1
# 24                                   f                               2
# 25                                   t                               1
# 26                                   f                               1
# 27                                   f                               1
# 28                                   f                               3
# 29                                   f                               1
# ...                                ...                             ...
# 59851                                f                               1
# 59852                                f                               1
# 59853                                f                               1
# 59854                                f                               2
# 59855                                f                               5
# 59856                                f                               1
# 59857                                f                               1
# 59858                                f                               2
# 59859                                f                               1
# 59860                                f                               1
# 59861                                f                               1
# 59862                                f                               1
# 59863                                f                               1
# 59864                                f                               2
# 59865                                f                               1
# 59866                                f                               2
# 59867                                f                               4
# 59868                                f                               2
# 59869                                f                               1
# 59870                                f                               1
# 59871                                f                              38
# 59872                                f                               2
# 59873                                f                               1
# 59874                                f                              25
# 59875                                f                               1
# 59876                                f                               2
# 59877                                f                               1
# 59878                                f                               1
# 59879                                f                               1
# 59880                                f                               1
#
#        reviews_per_month
# 0                    NaN
# 1                   0.29
# 2                   1.29
# 3                   2.47
# 4                   0.06
# 5                   0.01
# 6                    NaN
# 7                   0.24
# 8                   1.33
# 9                   1.46
# 10                  0.38
# 11                  0.17
# 12                  0.36
# 13                  2.86
# 14                  2.58
# 15                  0.43
# 16                  0.03
# 17                  0.98
# 18                  2.98
# 19                  0.01
# 20                  1.22
# 21                  0.16
# 22                  0.10
# 23                  2.02
# 24                  0.30
# 25                  3.11
# 26                  1.09
# 27                  0.52
# 28                  0.64
# 29                  0.12
# ...                  ...
# 59851                NaN
# 59852                NaN
# 59853                NaN
# 59854                NaN
# 59855                NaN
# 59856                NaN
# 59857                NaN
# 59858                NaN
# 59859                NaN
# 59860                NaN
# 59861                NaN
# 59862                NaN
# 59863                NaN
# 59864                NaN
# 59865                NaN
# 59866                NaN
# 59867                NaN
# 59868                NaN
# 59869                NaN
# 59870                NaN
# 59871                NaN
# 59872                NaN
# 59873                NaN
# 59874                NaN
# 59875                NaN
# 59876                NaN
# 59877               1.00
# 59878                NaN
# 59879                NaN
# 59880                NaN
#
# [59881 rows x 96 columns]

# %%
# TODO - Download and load dataset
df.columns
# Out:
# Index(['id', 'listing_url', 'scrape_id', 'last_scraped', 'name', 'summary',
#        'space', 'description', 'experiences_offered', 'neighborhood_overview',
#        'notes', 'transit', 'access', 'interaction', 'house_rules',
#        'thumbnail_url', 'medium_url', 'picture_url', 'xl_picture_url',
#        'host_id', 'host_url', 'host_name', 'host_since', 'host_location',
#        'host_about', 'host_response_time', 'host_response_rate',
#        'host_acceptance_rate', 'host_is_superhost', 'host_thumbnail_url',
#        'host_picture_url', 'host_neighbourhood', 'host_listings_count',
#        'host_total_listings_count', 'host_verifications',
#        'host_has_profile_pic', 'host_identity_verified', 'street',
#        'neighbourhood', 'neighbourhood_cleansed',
#        'neighbourhood_group_cleansed', 'city', 'state', 'zipcode', 'market',
#        'smart_location', 'country_code', 'country', 'latitude', 'longitude',
#        'is_location_exact', 'property_type', 'room_type', 'accommodates',
#        'bathrooms', 'bedrooms', 'beds', 'bed_type', 'amenities', 'square_feet',
#        'price', 'weekly_price', 'monthly_price', 'security_deposit',
#        'cleaning_fee', 'guests_included', 'extra_people', 'minimum_nights',
#        'maximum_nights', 'calendar_updated', 'has_availability',
#        'availability_30', 'availability_60', 'availability_90',
#        'availability_365', 'calendar_last_scraped', 'number_of_reviews',
#        'first_review', 'last_review', 'review_scores_rating',
#        'review_scores_accuracy', 'review_scores_cleanliness',
#        'review_scores_checkin', 'review_scores_communication',
#        'review_scores_location', 'review_scores_value', 'requires_license',
#        'license', 'jurisdiction_names', 'instant_bookable',
#        'is_business_travel_ready', 'cancellation_policy',
#        'require_guest_profile_picture', 'require_guest_phone_verification',
#        'calculated_host_listings_count', 'reviews_per_month'],
#       dtype='object')

# %% [markdown]
# **Q2**. Let's clean a bit this dataset:
# - Does it contain only data from Paris city? If not make sure to filter only on Paris listings.
# - Also, keep only listings with location as exact (`is_location_exact` column)

# %%
df['market'].value_counts()
# Out:
# Paris                    59711
# Other (International)        9
# Other (Domestic)             4
# Marseille                    3
# Dallas                       3
# Bordeaux                     2
# Basque Country               2
# Rome                         1
# Saint Malo                   1
# Aix                          1
# Orleans                      1
# Toulouse                     1
# Berlin                       1
# Loire Valley                 1
# Bogota                       1
# Brussels                     1
# Ardennes                     1
# Deauville                    1
# Buenos Aires                 1
# Evreux                       1
# Lille                        1
# Basilicata                   1
# Name: market, dtype: int64

# %%
#TODO - Clean ataset
df = df[df['market']=='Paris']
df = df[df['is_location_exact']=='t']
df.price.value_counts()
# Out:
# $60.00       2657
# $50.00       2607
# $70.00       2534
# $80.00       2526
# $100.00      2073
# $90.00       1966
# $65.00       1649
# $75.00       1579
# $55.00       1515
# $45.00       1455
# $40.00       1436
# $120.00      1422
# $150.00      1229
# $85.00       1116
# $110.00      1080
# $95.00        966
# $35.00        827
# $130.00       733
# $30.00        610
# $200.00       592
# $99.00        564
# $69.00        535
# $140.00       520
# $59.00        503
# $49.00        502
# $79.00        498
# $250.00       437
# $180.00       404
# $89.00        394
# $160.00       389
#              ...
# $293.00         1
# $9,379.00       1
# $338.00         1
# $452.00         1
# $465.00         1
# $637.00         1
# $402.00         1
# $292.00         1
# $622.00         1
# $432.00         1
# $683.00         1
# $392.00         1
# $508.00         1
# $1,090.00       1
# $586.00         1
# $222.00         1
# $909.00         1
# $467.00         1
# $8,803.00       1
# $697.00         1
# $606.00         1
# $8,576.00       1
# $605.00         1
# $1,972.00       1
# $459.00         1
# $528.00         1
# $382.00         1
# $636.00         1
# $3,355.00       1
# $1,600.00       1
# Name: price, Length: 547, dtype: int64

# %% [markdown]
# **Q3**. Let's understand better the listings price and draw some visualization with Seaborn
# - Observe price distribution with a **box plot** - Reference: https://en.wikipedia.org/wiki/Box_plot
# - Do you think there are some outliers? If yes, remove them
# - Finally, visualize the cleaned distribution of the listings price with a **histrogram plot**
# - Comment
#
# > 🔦 **Hint**:  You might want to clean the column before starting your analysis 🙂
# >
# > In order to apply a defined function `my_func` to a column (Series), you can use `apply` method:
# > ``` python
# >  data[column_name].apply(lambda x: my_func(x))
# > ```

# %%
df['price'] = df['price'].apply(lambda x: x.replace('$','').replace(',',''))
df['price'] = df['price'].astype(float)
df['price'].value_counts()


#TODO - Visualize Price Distribution
plt.figure(figsize=(12, 6))

sns.boxplot(x=df.price, data=df)
plt.title('Price')
plt.show()

# %%
#TODO - Visualize Price Distribution
df_new = df[df["price"]<160]
plt.figure(figsize=(12, 6))

sns.boxplot(x=df_new.price, data=df)
plt.title('Price')
plt.show()

# %% [markdown]
# **Q4**. Let's try to get a better understanding of price variation by visualizing geographically our data:
# - Visualize the listings categorized as "Entire Home/apt" on a map.
#
# > 🔦 **Hint**: No need for complex functions, `sns.scatterplot` should work perfectly!
#
# - Visualize this same map with varying color depending on the price
# - Make sure the column `neighbourhood_cleansed` is cleaned by observing the data points with varying color depending on the neighbourhood

# %%
#TODO - Geo Visualization
plt.figure(figsize=(15, 8))
plt.title("Listings Price Distribution")
sns.distplot(df_new["price"], bins=15)
plt.show()

# %% [markdown]
# **Q5**. Compute **median price depending on the neighbourhood**. Which districts appear the most and the less expensive?
#
# Draw a nice visualization of these prices discrepancies (differences).

# %%
plt.figure(figsize=(15, 8))
plt.title("Listings Price Distribution for airbnb in Paris")
sns.scatterplot(x="longitude", y="latitude", hue="price", palette="RdBu_r", data= df_new)
plt.show()

# %%
plt.figure(figsize=(15, 8))
plt.title("Listings neighbourhood")
sns.scatterplot(x="longitude", y="latitude", hue="neighbourhood_cleansed", palette="coolwarm", data= df_new)
plt.show()

# %%
#TODO - Price per district
df_new.columns

# %%
#TODO - Price per district
#price_nei = df_new.groupby("neighbourhood_cleansed")["price"].median()
df_new['neighbourhood_price']=my_l
#price_nei

# %%
df_new.head()

# %%
df_group = df_new.groupby("neighbourhood_cleansed")["price"].median()

# %%
df_new["neighbourhood_price"] = df_new["neighbourhood_cleansed"].apply(lambda x: df_group[x])
# Out:
# /Users/mickaelnunes/bin/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
plt.figure(figsize=(15, 8))
plt.title("Paris airbnb neighbourhood price per night ")
sns.scatterplot(x="longitude", y="latitude", hue="neighbourhood_price", palette="RdBu_r", data= df_new)
plt.show()

# %% [markdown]
# **Q6**. Play with the dataset and draw nice and impactful visualizations!

# %%
df_new[df_new['host_location']=='Paris, Île-de-France, France'].shape
df_group_location = df_new['host_location'].value_counts()
df_group_location

# %%
def location(x):
    if x=='Paris, Île-de-France, France' or x=='FR':
        return "French"
    else:
        return "Stranger"

# %%
df_new['host_location_group'] = df_new['host_location'].apply(lambda x: location(x))

# %%
plt.figure(figsize=(15, 8))
plt.title("Listings neighbourhood_price")
sns.scatterplot(x="longitude", y="latitude", hue="host_location_group", palette="coolwarm", data= df_new)
plt.show()

# %%
def location(x):
    if 'France' in x:
        return "French"
    else:
        return "Stranger"

# %%
df_new['Paris'] = df_new['host_location'].apply(lambda x: location(x))

# %%
df_new['Paris'].value_counts()

# %%
plt.figure(figsize=(15, 8))
plt.title("Listings neighbourhood_price")
sns.scatterplot(x="longitude", y="latitude", hue="Paris", palette="coolwarm", data= df_new)
plt.show()
